# %% [markdown]
# # AutoML and Hyperparameter Training
#
# Here I use Automatic Machine Learning tools to quickly and efficently assess a range of potential models

# %% [markdown]
# ## Import Packages

# %%
# plotting
import matplotlib.pyplot as plt

# general
import pandas as pd
import numpy as np
import calendar

# ml
from pycaret.regression import *

# %% [markdown]
# ## Import data
#
# This is my first time combining the PCs and the PWT data I'm trying to emulate, so I'm taking a bit of work below to get them into the same format

# %%
# set lists of coordinates and time ranges (pulled from Prepare_AI_Ready_Data.py) (CURRENTLY JUST ONE, BUT CAN ADD MORE)
coords = [[180,240,45,65],[130,250,20,75]]
times = [['1970-01-01','2023-12-31']]  # Ensure the time range is valid

# select which of the list I want to load
coords_num = 1
times_num = 0

# pull the correct coordinate and time (as set above)
c = coords[coords_num]
t = times[times_num]

# Import Target Data
pc_df_raw = pd.read_csv(f'../data/dimensionality_reduction/principal_components_{c[0]}-{c[1]}_{c[2]}-{c[3]}_{t[0][:4]}-{t[1][:4]}.csv')

# %%
target_df_raw = pd.read_csv('../data/target/era5_monthbymonth_pwt.csv')

# delete all columns which contain 'ann' in the column name
target_df_raw = target_df_raw.loc[:,~target_df_raw.columns.str.contains('ann')]

# %%
# sort imported data into same format as training data

# identify all column names that contain 'jan'
jan_cols = target_df_raw.columns[target_df_raw.columns.str.contains('jan')]

# remove '_jan' from column names
new_cols = [col.replace('_jan','') for col in jan_cols]

# add new_cols as empty columns to the pc_df_raw dataframe
master_df = pc_df_raw.copy()
for col in new_cols:
    master_df[col] = np.nan

# loop throuch pc_df_raw row by row and add the corresponding january data to the new dataframe
for index, row in master_df.iterrows():

    # get year, month from 'time' column
    year = int(row['time'].split('-')[0])
    month = int(row['time'].split('-')[1])

    # get 3-character month string from month integer (i.e. 1 -> 'jan')
    month_str = calendar.month_abbr[month].lower()

    # find the corresponding row in the target dataframe
    target_row = target_df_raw.loc[target_df_raw['Year'] == year]

    for col in jan_cols:
        
        # get the corresponding column name
        c = col.replace('_jan','_'+month_str)

        # remove '_jan' from column name
        nc = col.replace('_jan','')

        # get the value from the target dataframe
        value = target_row[c].values[0]

        # add the value to the new dataframe
        master_df.at[index, nc] = value
    
# convert time (format as string 'YYYY/MM/DD') to datetime
master_df['time'] = pd.to_datetime(master_df['time'])

# add a month column to the df
master_df['month'] = master_df['time'].dt.month

# remove rows with year > 2022
master_df = master_df[master_df['time'] < '2023-01-01']

# print head to confirm
print(master_df.head())

# save dataframe in this format (for use in other scripts)
master_df.to_csv(f'../data/dimensionality_reduction/principal_components_{c[0]}-{c[1]}_{c[2]}-{c[3]}_{t[0][:4]}-{t[1][:4]}_target.csv', index=False)
# Out:
#             PC1           PC2           PC3           PC4          PC5  \
# 0  26011.582895  16179.864478  20148.257224  -1243.128472 -3203.919113
# 1 -38540.276288 -26933.230459   7662.333731   -473.188801  -574.772963
# 2 -27748.077675 -27043.209357   6201.702439 -12455.893354 -5782.296933
# 3    914.655777  -1933.663131 -17384.504214  -8083.327042 -8493.886231
# 4   4350.635969   8551.012038   3549.986502  -8621.343188  6588.165550
#
#            PC6          PC7          PC8          PC9         PC10  ...  \
# 0  2082.483822  1533.300644 -2073.035967  -403.748801 -1831.821897  ...
# 1  -283.820441 -3347.927477  -806.090809  1080.197321 -1307.212841  ...
# 2   890.853223   769.349049 -2303.218959  4509.428779  -212.349491  ...
# 3  1760.217848   299.825646 -2445.984972  2386.216683  -413.029896  ...
# 4  1714.238166 -3375.579228   267.801280  1445.144680   843.720135  ...
#
#    pwt_800hpa  pwt_825hpa  pwt_850hpa  pwt_875hpa  pwt_900hpa  pwt_925hpa  \
# 0  264.275124  265.928571  267.571081  268.893416  270.386999  271.847994
# 1  265.927490  267.622376  269.234110  270.601442  272.119173  273.598054
# 2  264.579053  266.240869  267.787653  269.213114  270.674344  272.107772
# 3  262.960202  264.579725  266.204628  267.644252  269.060192  270.453064
# 4  268.149969  269.746534  271.301340  272.786989  274.270468  275.689503
#
#    pwt_950hpa  pwt_975hpa  pwt_1000hpa  month
# 0  273.187784  274.572595   275.900261      1
# 1  274.961653  276.358129   277.702489      2
# 2  273.493896  274.877041   276.195554      3
# 3  271.822730  273.184327   274.497279      4
# 4  277.081869  278.456398   279.796935      5
#
# [5 rows x 35 columns]

# %% [markdown]
# ## Apply autoML Frameworks
#
# Here I apply pycaret to automate machine learning model selection along with hyperparameter tuning. I used CoPilot to efficiently set this up. Does this mean we can call this auto-autoML?

# %%
# filter for just the columns I want (PC1-PC10, and pwt_500hpa)
automl_data = master_df[['PC1','PC2','PC3','PC4','PC5','PC6','PC7','PC8','PC9','PC10','month','pwt_500hpa']]

# check for missing or nan values
print(automl_data.isnull().sum())

# check all values are floats
print(automl_data.dtypes)

# normalize all features and target to be between 0 and 1
automl_data = automl_data.apply(lambda x: (x - x.min()) / (x.max() - x.min()))

# check the data
automl_data.head()
# Out:
# PC1           0
# PC2           0
# PC3           0
# PC4           0
# PC5           0
# PC6           0
# PC7           0
# PC8           0
# PC9           0
# PC10          0
# month         0
# pwt_500hpa    0
# dtype: int64
# PC1           float64
# PC2           float64
# PC3           float64
# PC4           float64
# PC5           float64
# PC6           float64
# PC7           float64
# PC8           float64
# PC9           float64
# PC10          float64
# month           int32
# pwt_500hpa    float64
# dtype: object
#         PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 0  0.600002  0.637487  0.638194  0.425833  0.337849  0.472255  0.540526
# 1  0.281566  0.220377  0.505401  0.438916  0.411108  0.392262  0.261215
# 2  0.334804  0.219313  0.489866  0.235291  0.266006  0.431972  0.496812
# 3  0.476198  0.462243  0.239016  0.309595  0.190450  0.461360  0.469945
# 4  0.493148  0.563680  0.461664  0.300453  0.610695  0.459806  0.259632
#
#         PC8       PC9      PC10     month  pwt_500hpa
# 0  0.331680  0.424085  0.308266  0.000000    0.165404
# 1  0.424446  0.539133  0.359890  0.090909    0.335815
# 2  0.314826  0.804997  0.467631  0.181818    0.231047
# 3  0.304372  0.640387  0.447883  0.272727    0.223241
# 4  0.503077  0.567427  0.571554  0.363636    0.343418

# %%
# Initialize PyCaret setup
setup(data=automl_data, 
      target='pwt_500hpa', 
      session_id=123,
      normalize=False,        
      transformation=True,   
      fold=5,                
      verbose=True)
# Out:
# <style type="text/css">
# #T_1635a_row8_col1, #T_1635a_row12_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_1635a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1635a_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_1635a_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1635a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1635a_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_1635a_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_1635a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1635a_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_1635a_row1_col1" class="data row1 col1" >pwt_500hpa</td>
#     </tr>
#     <tr>
#       <th id="T_1635a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_1635a_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_1635a_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_1635a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_1635a_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_1635a_row3_col1" class="data row3 col1" >(636, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_1635a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_1635a_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_1635a_row4_col1" class="data row4 col1" >(636, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_1635a_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_1635a_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_1635a_row5_col1" class="data row5 col1" >(445, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_1635a_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_1635a_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_1635a_row6_col1" class="data row6 col1" >(191, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_1635a_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_1635a_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_1635a_row7_col1" class="data row7 col1" >11</td>
#     </tr>
#     <tr>
#       <th id="T_1635a_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_1635a_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_1635a_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_1635a_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_1635a_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_1635a_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_1635a_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_1635a_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_1635a_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_1635a_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_1635a_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_1635a_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_1635a_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_1635a_row12_col0" class="data row12 col0" >Transformation</td>
#       <td id="T_1635a_row12_col1" class="data row12 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_1635a_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_1635a_row13_col0" class="data row13 col0" >Transformation method</td>
#       <td id="T_1635a_row13_col1" class="data row13 col1" >yeo-johnson</td>
#     </tr>
#     <tr>
#       <th id="T_1635a_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_1635a_row14_col0" class="data row14 col0" >Fold Generator</td>
#       <td id="T_1635a_row14_col1" class="data row14 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_1635a_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_1635a_row15_col0" class="data row15 col0" >Fold Number</td>
#       <td id="T_1635a_row15_col1" class="data row15 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_1635a_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_1635a_row16_col0" class="data row16 col0" >CPU Jobs</td>
#       <td id="T_1635a_row16_col1" class="data row16 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_1635a_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_1635a_row17_col0" class="data row17 col0" >Use GPU</td>
#       <td id="T_1635a_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_1635a_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_1635a_row18_col0" class="data row18 col0" >Log Experiment</td>
#       <td id="T_1635a_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_1635a_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_1635a_row19_col0" class="data row19 col0" >Experiment Name</td>
#       <td id="T_1635a_row19_col1" class="data row19 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_1635a_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_1635a_row20_col0" class="data row20 col0" >USI</td>
#       <td id="T_1635a_row20_col1" class="data row20 col1" >b2cd</td>
#     </tr>
#   </tbody>
# </table>

# %%
best = compare_models(exclude = ['ransac'])
# Out:
# <style type="text/css">
# #T_003da th {
#   text-align: left;
# }
# #T_003da_row0_col0, #T_003da_row1_col0, #T_003da_row1_col1, #T_003da_row1_col2, #T_003da_row1_col3, #T_003da_row1_col4, #T_003da_row1_col5, #T_003da_row1_col6, #T_003da_row2_col0, #T_003da_row2_col1, #T_003da_row2_col2, #T_003da_row2_col3, #T_003da_row2_col4, #T_003da_row2_col5, #T_003da_row2_col6, #T_003da_row3_col0, #T_003da_row3_col1, #T_003da_row3_col2, #T_003da_row3_col3, #T_003da_row3_col4, #T_003da_row3_col5, #T_003da_row3_col6, #T_003da_row4_col0, #T_003da_row4_col1, #T_003da_row4_col2, #T_003da_row4_col3, #T_003da_row4_col4, #T_003da_row4_col5, #T_003da_row4_col6, #T_003da_row5_col0, #T_003da_row5_col1, #T_003da_row5_col2, #T_003da_row5_col3, #T_003da_row5_col4, #T_003da_row5_col5, #T_003da_row5_col6, #T_003da_row6_col0, #T_003da_row6_col1, #T_003da_row6_col2, #T_003da_row6_col3, #T_003da_row6_col4, #T_003da_row6_col5, #T_003da_row6_col6, #T_003da_row7_col0, #T_003da_row7_col1, #T_003da_row7_col2, #T_003da_row7_col3, #T_003da_row7_col4, #T_003da_row7_col5, #T_003da_row7_col6, #T_003da_row8_col0, #T_003da_row8_col1, #T_003da_row8_col2, #T_003da_row8_col3, #T_003da_row8_col4, #T_003da_row8_col5, #T_003da_row8_col6, #T_003da_row9_col0, #T_003da_row9_col1, #T_003da_row9_col2, #T_003da_row9_col3, #T_003da_row9_col4, #T_003da_row9_col5, #T_003da_row9_col6, #T_003da_row10_col0, #T_003da_row10_col1, #T_003da_row10_col2, #T_003da_row10_col3, #T_003da_row10_col4, #T_003da_row10_col5, #T_003da_row10_col6, #T_003da_row11_col0, #T_003da_row11_col1, #T_003da_row11_col2, #T_003da_row11_col3, #T_003da_row11_col4, #T_003da_row11_col5, #T_003da_row11_col6, #T_003da_row12_col0, #T_003da_row12_col1, #T_003da_row12_col2, #T_003da_row12_col3, #T_003da_row12_col4, #T_003da_row12_col5, #T_003da_row12_col6, #T_003da_row13_col0, #T_003da_row13_col1, #T_003da_row13_col2, #T_003da_row13_col3, #T_003da_row13_col4, #T_003da_row13_col5, #T_003da_row13_col6, #T_003da_row14_col0, #T_003da_row14_col1, #T_003da_row14_col2, #T_003da_row14_col3, #T_003da_row14_col4, #T_003da_row14_col5, #T_003da_row14_col6, #T_003da_row15_col0, #T_003da_row15_col1, #T_003da_row15_col2, #T_003da_row15_col3, #T_003da_row15_col4, #T_003da_row15_col5, #T_003da_row15_col6, #T_003da_row16_col0, #T_003da_row16_col1, #T_003da_row16_col2, #T_003da_row16_col3, #T_003da_row16_col4, #T_003da_row16_col5, #T_003da_row16_col6, #T_003da_row17_col0, #T_003da_row17_col1, #T_003da_row17_col2, #T_003da_row17_col3, #T_003da_row17_col4, #T_003da_row17_col5, #T_003da_row17_col6, #T_003da_row18_col0, #T_003da_row18_col1, #T_003da_row18_col2, #T_003da_row18_col3, #T_003da_row18_col4, #T_003da_row18_col5, #T_003da_row18_col6, #T_003da_row19_col0, #T_003da_row19_col1, #T_003da_row19_col2, #T_003da_row19_col3, #T_003da_row19_col4, #T_003da_row19_col5, #T_003da_row19_col6 {
#   text-align: left;
# }
# #T_003da_row0_col1, #T_003da_row0_col2, #T_003da_row0_col3, #T_003da_row0_col4, #T_003da_row0_col5, #T_003da_row0_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_003da_row0_col7, #T_003da_row1_col7, #T_003da_row2_col7, #T_003da_row3_col7, #T_003da_row4_col7, #T_003da_row5_col7, #T_003da_row6_col7, #T_003da_row7_col7, #T_003da_row8_col7, #T_003da_row9_col7, #T_003da_row10_col7, #T_003da_row11_col7, #T_003da_row12_col7, #T_003da_row14_col7, #T_003da_row15_col7, #T_003da_row16_col7, #T_003da_row17_col7, #T_003da_row19_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_003da_row13_col7, #T_003da_row18_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_003da">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_003da_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_003da_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_003da_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_003da_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_003da_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_003da_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_003da_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_003da_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_003da_level0_row0" class="row_heading level0 row0" >et</th>
#       <td id="T_003da_row0_col0" class="data row0 col0" >Extra Trees Regressor</td>
#       <td id="T_003da_row0_col1" class="data row0 col1" >0.0653</td>
#       <td id="T_003da_row0_col2" class="data row0 col2" >0.0071</td>
#       <td id="T_003da_row0_col3" class="data row0 col3" >0.0839</td>
#       <td id="T_003da_row0_col4" class="data row0 col4" >0.8513</td>
#       <td id="T_003da_row0_col5" class="data row0 col5" >0.0614</td>
#       <td id="T_003da_row0_col6" class="data row0 col6" >0.2420</td>
#       <td id="T_003da_row0_col7" class="data row0 col7" >0.0320</td>
#     </tr>
#     <tr>
#       <th id="T_003da_level0_row1" class="row_heading level0 row1" >rf</th>
#       <td id="T_003da_row1_col0" class="data row1 col0" >Random Forest Regressor</td>
#       <td id="T_003da_row1_col1" class="data row1 col1" >0.0665</td>
#       <td id="T_003da_row1_col2" class="data row1 col2" >0.0075</td>
#       <td id="T_003da_row1_col3" class="data row1 col3" >0.0864</td>
#       <td id="T_003da_row1_col4" class="data row1 col4" >0.8413</td>
#       <td id="T_003da_row1_col5" class="data row1 col5" >0.0634</td>
#       <td id="T_003da_row1_col6" class="data row1 col6" >0.2460</td>
#       <td id="T_003da_row1_col7" class="data row1 col7" >0.0480</td>
#     </tr>
#     <tr>
#       <th id="T_003da_level0_row2" class="row_heading level0 row2" >gbr</th>
#       <td id="T_003da_row2_col0" class="data row2 col0" >Gradient Boosting Regressor</td>
#       <td id="T_003da_row2_col1" class="data row2 col1" >0.0665</td>
#       <td id="T_003da_row2_col2" class="data row2 col2" >0.0077</td>
#       <td id="T_003da_row2_col3" class="data row2 col3" >0.0878</td>
#       <td id="T_003da_row2_col4" class="data row2 col4" >0.8362</td>
#       <td id="T_003da_row2_col5" class="data row2 col5" >0.0644</td>
#       <td id="T_003da_row2_col6" class="data row2 col6" >0.2500</td>
#       <td id="T_003da_row2_col7" class="data row2 col7" >0.0460</td>
#     </tr>
#     <tr>
#       <th id="T_003da_level0_row3" class="row_heading level0 row3" >catboost</th>
#       <td id="T_003da_row3_col0" class="data row3 col0" >CatBoost Regressor</td>
#       <td id="T_003da_row3_col1" class="data row3 col1" >0.0689</td>
#       <td id="T_003da_row3_col2" class="data row3 col2" >0.0081</td>
#       <td id="T_003da_row3_col3" class="data row3 col3" >0.0896</td>
#       <td id="T_003da_row3_col4" class="data row3 col4" >0.8295</td>
#       <td id="T_003da_row3_col5" class="data row3 col5" >0.0654</td>
#       <td id="T_003da_row3_col6" class="data row3 col6" >0.2590</td>
#       <td id="T_003da_row3_col7" class="data row3 col7" >0.4420</td>
#     </tr>
#     <tr>
#       <th id="T_003da_level0_row4" class="row_heading level0 row4" >lightgbm</th>
#       <td id="T_003da_row4_col0" class="data row4 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_003da_row4_col1" class="data row4 col1" >0.0681</td>
#       <td id="T_003da_row4_col2" class="data row4 col2" >0.0082</td>
#       <td id="T_003da_row4_col3" class="data row4 col3" >0.0903</td>
#       <td id="T_003da_row4_col4" class="data row4 col4" >0.8266</td>
#       <td id="T_003da_row4_col5" class="data row4 col5" >0.0666</td>
#       <td id="T_003da_row4_col6" class="data row4 col6" >0.2594</td>
#       <td id="T_003da_row4_col7" class="data row4 col7" >0.2400</td>
#     </tr>
#     <tr>
#       <th id="T_003da_level0_row5" class="row_heading level0 row5" >xgboost</th>
#       <td id="T_003da_row5_col0" class="data row5 col0" >Extreme Gradient Boosting</td>
#       <td id="T_003da_row5_col1" class="data row5 col1" >0.0718</td>
#       <td id="T_003da_row5_col2" class="data row5 col2" >0.0085</td>
#       <td id="T_003da_row5_col3" class="data r

# %%
evaluate_model(best)

# print hyperparameters of best model
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
# evaluate the 2nd best model
best2 = compare_models(exclude = ['ransac', best])
evaluate_model(best2)
# Out:
# <style type="text/css">
# #T_ec74c th {
#   text-align: left;
# }
# #T_ec74c_row0_col0, #T_ec74c_row1_col0, #T_ec74c_row1_col1, #T_ec74c_row1_col2, #T_ec74c_row1_col3, #T_ec74c_row1_col4, #T_ec74c_row1_col5, #T_ec74c_row1_col6, #T_ec74c_row2_col0, #T_ec74c_row2_col1, #T_ec74c_row2_col2, #T_ec74c_row2_col3, #T_ec74c_row2_col4, #T_ec74c_row2_col5, #T_ec74c_row2_col6, #T_ec74c_row3_col0, #T_ec74c_row3_col1, #T_ec74c_row3_col2, #T_ec74c_row3_col3, #T_ec74c_row3_col4, #T_ec74c_row3_col5, #T_ec74c_row3_col6, #T_ec74c_row4_col0, #T_ec74c_row4_col1, #T_ec74c_row4_col2, #T_ec74c_row4_col3, #T_ec74c_row4_col4, #T_ec74c_row4_col5, #T_ec74c_row4_col6, #T_ec74c_row5_col0, #T_ec74c_row5_col1, #T_ec74c_row5_col2, #T_ec74c_row5_col3, #T_ec74c_row5_col4, #T_ec74c_row5_col5, #T_ec74c_row5_col6, #T_ec74c_row6_col0, #T_ec74c_row6_col1, #T_ec74c_row6_col2, #T_ec74c_row6_col3, #T_ec74c_row6_col4, #T_ec74c_row6_col5, #T_ec74c_row6_col6, #T_ec74c_row7_col0, #T_ec74c_row7_col1, #T_ec74c_row7_col2, #T_ec74c_row7_col3, #T_ec74c_row7_col4, #T_ec74c_row7_col5, #T_ec74c_row7_col6, #T_ec74c_row8_col0, #T_ec74c_row8_col1, #T_ec74c_row8_col2, #T_ec74c_row8_col3, #T_ec74c_row8_col4, #T_ec74c_row8_col5, #T_ec74c_row8_col6, #T_ec74c_row9_col0, #T_ec74c_row9_col1, #T_ec74c_row9_col2, #T_ec74c_row9_col3, #T_ec74c_row9_col4, #T_ec74c_row9_col5, #T_ec74c_row9_col6, #T_ec74c_row10_col0, #T_ec74c_row10_col1, #T_ec74c_row10_col2, #T_ec74c_row10_col3, #T_ec74c_row10_col4, #T_ec74c_row10_col5, #T_ec74c_row10_col6, #T_ec74c_row11_col0, #T_ec74c_row11_col1, #T_ec74c_row11_col2, #T_ec74c_row11_col3, #T_ec74c_row11_col4, #T_ec74c_row11_col5, #T_ec74c_row11_col6, #T_ec74c_row12_col0, #T_ec74c_row12_col1, #T_ec74c_row12_col2, #T_ec74c_row12_col3, #T_ec74c_row12_col4, #T_ec74c_row12_col5, #T_ec74c_row12_col6, #T_ec74c_row13_col0, #T_ec74c_row13_col1, #T_ec74c_row13_col2, #T_ec74c_row13_col3, #T_ec74c_row13_col4, #T_ec74c_row13_col5, #T_ec74c_row13_col6, #T_ec74c_row14_col0, #T_ec74c_row14_col1, #T_ec74c_row14_col2, #T_ec74c_row14_col3, #T_ec74c_row14_col4, #T_ec74c_row14_col5, #T_ec74c_row14_col6, #T_ec74c_row15_col0, #T_ec74c_row15_col1, #T_ec74c_row15_col2, #T_ec74c_row15_col3, #T_ec74c_row15_col4, #T_ec74c_row15_col5, #T_ec74c_row15_col6, #T_ec74c_row16_col0, #T_ec74c_row16_col1, #T_ec74c_row16_col2, #T_ec74c_row16_col3, #T_ec74c_row16_col4, #T_ec74c_row16_col5, #T_ec74c_row16_col6, #T_ec74c_row17_col0, #T_ec74c_row17_col1, #T_ec74c_row17_col2, #T_ec74c_row17_col3, #T_ec74c_row17_col4, #T_ec74c_row17_col5, #T_ec74c_row17_col6, #T_ec74c_row18_col0, #T_ec74c_row18_col1, #T_ec74c_row18_col2, #T_ec74c_row18_col3, #T_ec74c_row18_col4, #T_ec74c_row18_col5, #T_ec74c_row18_col6, #T_ec74c_row19_col0, #T_ec74c_row19_col1, #T_ec74c_row19_col2, #T_ec74c_row19_col3, #T_ec74c_row19_col4, #T_ec74c_row19_col5, #T_ec74c_row19_col6 {
#   text-align: left;
# }
# #T_ec74c_row0_col1, #T_ec74c_row0_col2, #T_ec74c_row0_col3, #T_ec74c_row0_col4, #T_ec74c_row0_col5, #T_ec74c_row0_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_ec74c_row0_col7, #T_ec74c_row1_col7, #T_ec74c_row2_col7, #T_ec74c_row3_col7, #T_ec74c_row4_col7, #T_ec74c_row5_col7, #T_ec74c_row6_col7, #T_ec74c_row8_col7, #T_ec74c_row12_col7, #T_ec74c_row13_col7, #T_ec74c_row14_col7, #T_ec74c_row15_col7, #T_ec74c_row17_col7, #T_ec74c_row18_col7, #T_ec74c_row19_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_ec74c_row7_col7, #T_ec74c_row9_col7, #T_ec74c_row10_col7, #T_ec74c_row11_col7, #T_ec74c_row16_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_ec74c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ec74c_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_ec74c_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_ec74c_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_ec74c_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_ec74c_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_ec74c_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_ec74c_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_ec74c_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ec74c_level0_row0" class="row_heading level0 row0" >et</th>
#       <td id="T_ec74c_row0_col0" class="data row0 col0" >Extra Trees Regressor</td>
#       <td id="T_ec74c_row0_col1" class="data row0 col1" >0.0653</td>
#       <td id="T_ec74c_row0_col2" class="data row0 col2" >0.0071</td>
#       <td id="T_ec74c_row0_col3" class="data row0 col3" >0.0839</td>
#       <td id="T_ec74c_row0_col4" class="data row0 col4" >0.8513</td>
#       <td id="T_ec74c_row0_col5" class="data row0 col5" >0.0614</td>
#       <td id="T_ec74c_row0_col6" class="data row0 col6" >0.2420</td>
#       <td id="T_ec74c_row0_col7" class="data row0 col7" >0.0360</td>
#     </tr>
#     <tr>
#       <th id="T_ec74c_level0_row1" class="row_heading level0 row1" >rf</th>
#       <td id="T_ec74c_row1_col0" class="data row1 col0" >Random Forest Regressor</td>
#       <td id="T_ec74c_row1_col1" class="data row1 col1" >0.0665</td>
#       <td id="T_ec74c_row1_col2" class="data row1 col2" >0.0075</td>
#       <td id="T_ec74c_row1_col3" class="data row1 col3" >0.0864</td>
#       <td id="T_ec74c_row1_col4" class="data row1 col4" >0.8413</td>
#       <td id="T_ec74c_row1_col5" class="data row1 col5" >0.0634</td>
#       <td id="T_ec74c_row1_col6" class="data row1 col6" >0.2460</td>
#       <td id="T_ec74c_row1_col7" class="data row1 col7" >0.0540</td>
#     </tr>
#     <tr>
#       <th id="T_ec74c_level0_row2" class="row_heading level0 row2" >gbr</th>
#       <td id="T_ec74c_row2_col0" class="data row2 col0" >Gradient Boosting Regressor</td>
#       <td id="T_ec74c_row2_col1" class="data row2 col1" >0.0665</td>
#       <td id="T_ec74c_row2_col2" class="data row2 col2" >0.0077</td>
#       <td id="T_ec74c_row2_col3" class="data row2 col3" >0.0878</td>
#       <td id="T_ec74c_row2_col4" class="data row2 col4" >0.8362</td>
#       <td id="T_ec74c_row2_col5" class="data row2 col5" >0.0644</td>
#       <td id="T_ec74c_row2_col6" class="data row2 col6" >0.2500</td>
#       <td id="T_ec74c_row2_col7" class="data row2 col7" >0.0360</td>
#     </tr>
#     <tr>
#       <th id="T_ec74c_level0_row3" class="row_heading level0 row3" >catboost</th>
#       <td id="T_ec74c_row3_col0" class="data row3 col0" >CatBoost Regressor</td>
#       <td id="T_ec74c_row3_col1" class="data row3 col1" >0.0689</td>
#       <td id="T_ec74c_row3_col2" class="data row3 col2" >0.0081</td>
#       <td id="T_ec74c_row3_col3" class="data row3 col3" >0.0896</td>
#       <td id="T_ec74c_row3_col4" class="data row3 col4" >0.8295</td>
#       <td id="T_ec74c_row3_col5" class="data row3 col5" >0.0654</td>
#       <td id="T_ec74c_row3_col6" class="data row3 col6" >0.2590</td>
#       <td id="T_ec74c_row3_col7" class="data row3 col7" >0.5640</td>
#     </tr>
#     <tr>
#       <th id="T_ec74c_level0_row4" class="row_heading level0 row4" >lightgbm</th>
#       <td id="T_ec74c_row4_col0" class="data row4 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_ec74c_row4_col1" class="data row4 col1" >0.0681</td>
#       <td id="T_ec74c_row4_col2" class="data row4 col2" >0.0082</td>
#       <td id="T_ec74c_row4_col3" class="data row4 col3" >0.0903</td>
#       <td id="T_ec74c_row4_col4" class="data row4 col4" >0.8266</td>
#       <td id="T_ec74c_row4_col5" class="data row4 col5" >0.0666</td>
#       <td id="T_ec74c_row4_col6" class="data row4 col6" >0.2594</td>
#       <td id="T_ec74c_row4_col7" class="data row4 col7" >0.2400</td>
#     </tr>
#     <tr>
#       <th id="T_ec74c_level0_row5" class="row_heading level0 row5" >xgboost</th>
#       <td id="T_ec74c_row5_col0" class="data row5 col0" >Extreme Gradient Boosting</td>
#       <td id="T_ec74c_row5_col1" class="data row5 col1" >0.0718</td>
#       <td id="T_ec74c_row5_col2" class="data row5 col2" >0.0085</td>
#       <td id="T_ec74c_row5_col3" class="data r
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…
