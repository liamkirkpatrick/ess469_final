# %% [markdown]
# # AutoML and Hyperparameter Training
#
# Here I use Automatic Machine Learning tools to quickly and efficently assess a range of potential models

# %% [markdown]
# ## Import Packages

# %%
# plotting
import matplotlib.pyplot as plt

# general
import pandas as pd
import numpy as np
import calendar

# ml
from pycaret.regression import *

# %% [markdown]
# ## Import data
#
# This is my first time combining the PCs and the PWT data I'm trying to emulate, so I'm taking a bit of work below to get them into the same format

# %%
# set target (what are we trying to predict)
target = 'pwt_500hpa'
#target = 'temperature_800hpa'
#target = 'precipitation'

# %%
# set lists of coordinates and time ranges (pulled from Prepare_AI_Ready_Data.py) (CURRENTLY JUST ONE, BUT CAN ADD MORE)
coords = [[180,240,45,65],[130,250,20,75]]
times = [['1940-01-01','2023-12-31']]  # Ensure the time range is valid

# set PC option - seperate or combined
#PC_option = 'combined'
PC_option = 'seperate'

# select which of the list I want to load
coords_num = 1
times_num = 0

# pull the correct coordinate and time (as set above)
c = coords[coords_num]
t = times[times_num]

# read in PCs
if PC_option == 'combined':
    pc_df_raw = pd.read_csv(f'../data/dimensionality_reduction/principal_components_combined_{c[0]}-{c[1]}_{c[2]}-{c[3]}_{t[0][:4]}-{t[1][:4]}.csv')
elif PC_option == 'seperate':
    pc_df_raw = pd.read_csv(f'../data/dimensionality_reduction/principal_components_seperate_{c[0]}-{c[1]}_{c[2]}-{c[3]}_{t[0][:4]}-{t[1][:4]}.csv')

# %%
target_df_raw = pd.read_csv('../data/target/era5_monthbymonth_allvars.csv')

# rename the 'Time' column to 'time' in the target data
target_df_raw.rename(columns={'Time':'time'}, inplace=True)

# look through all columns, change any 'PWT' in column names to 'pwt'
target_df_raw.columns = [i.lower() for i in target_df_raw.columns]

# merge teh pc and target data. Delete rows where the 'time' column doesn't overlap
master_df = pd.merge(pc_df_raw, target_df_raw, on='time', how='inner')

# add a column for the month
master_df['month'] = pd.to_datetime(master_df['time']).dt.month

# Preform one-hot encoding on the month column
master_df = pd.get_dummies(master_df, columns=['month'])

# save the master_df (for use in subsequent scripts)
master_df.to_csv(f'../data/dimensionality_reduction/principal_components_{PC_option}_{c[0]}-{c[1]}_{c[2]}-{c[3]}_{t[0][:4]}-{t[1][:4]}_target.csv', index=False)

# %%
master_df.columns
# Out:
# Index(['PC1_sst', 'PC2_sst', 'PC3_sst', 'PC4_sst', 'PC5_sst', 'PC6_sst',
#        'PC7_sst', 'PC8_sst', 'PC9_sst', 'PC10_sst', 'time', 'PC1_msl',
#        'PC2_msl', 'PC3_msl', 'PC4_msl', 'PC5_msl', 'PC6_msl', 'PC7_msl',
#        'PC8_msl', 'PC9_msl', 'PC10_msl', 'PC1_z', 'PC2_z', 'PC3_z', 'PC4_z',
#        'PC5_z', 'PC6_z', 'PC7_z', 'PC8_z', 'PC9_z', 'PC10_z', 'precipitation',
#        'temperature_200hpa', 'pwt_200hpa', 'temperature_250hpa', 'pwt_250hpa',
#        'temperature_300hpa', 'pwt_300hpa', 'temperature_350hpa', 'pwt_350hpa',
#        'temperature_400hpa', 'pwt_400hpa', 'temperature_450hpa', 'pwt_450hpa',
#        'temperature_500hpa', 'pwt_500hpa', 'temperature_550hpa', 'pwt_550hpa',
#        'temperature_600hpa', 'pwt_600hpa', 'temperature_650hpa', 'pwt_650hpa',
#        'temperature_700hpa', 'pwt_700hpa', 'temperature_750hpa', 'pwt_750hpa',
#        'temperature_775hpa', 'pwt_775hpa', 'temperature_800hpa', 'pwt_800hpa',
#        'temperature_825hpa', 'pwt_825hpa', 'temperature_850hpa', 'pwt_850hpa',
#        'temperature_875hpa', 'pwt_875hpa', 'temperature_900hpa', 'pwt_900hpa',
#        'temperature_925hpa', 'pwt_925hpa', 'temperature_950hpa', 'pwt_950hpa',
#        'temperature_975hpa', 'pwt_975hpa', 'temperature_1000hpa',
#        'pwt_1000hpa', 'month_1', 'month_2', 'month_3', 'month_4', 'month_5',
#        'month_6', 'month_7', 'month_8', 'month_9', 'month_10', 'month_11',
#        'month_12'],
#       dtype='object')

# %% [markdown]
# ## Apply autoML Frameworks
#
# Here I apply pycaret to automate machine learning model selection along with hyperparameter tuning. I used CoPilot to efficiently set this up. Does this mean we can call this auto-autoML?

# %%
# Keep only columns that are target, contain "PC", or contain "month"
columns_to_keep = [col for col in master_df.columns if target in col or "PC" in col or "month" in col]
automl_data = master_df[columns_to_keep]

# remove any columns that begin with PC# where the # is greater than 7 or equal to 10
#automl_data = automl_data.loc[:, ~automl_data.columns.str.contains('^PC([6-9]|10)')]

#  filter for just the columns I want (PC1-PC10, and pwt_500hpa)
# automl_data = master_df[['PC1', 'PC2', 'PC3', 'PC4', 'PC5', 'PC6', 'PC7', 'PC8', 'PC9', 'PC10', target, 
#                          'month_1', 'month_2', 'month_3', 'month_4', 'month_5', 'month_6', 'month_7', 'month_8', 
#                          'month_9', 'month_10', 'month_11', 'month_12']]
#automl_data = master_df[['PC1', 'PC2', 'PC3', 'PC4', 'PC5', 'PC6', 'PC7', 'PC8', 'PC9', 'PC10', 'pwt_500hpa']]

# check for missing or nan values
print(automl_data.isnull().sum())

# check all values are floats
print(automl_data.dtypes)

# normalize all features and target to be between 0 and 1 (except the month columns)
for col in automl_data.columns:
    if 'month' not in col:
        automl_data[col] = (automl_data[col] - automl_data[col].min()) / (automl_data[col].max() - automl_data[col].min())

# check the data
automl_data.head()
# Out:
# PC1_sst       0
# PC2_sst       0
# PC3_sst       0
# PC4_sst       0
# PC5_sst       0
# PC6_sst       0
# PC7_sst       0
# PC8_sst       0
# PC9_sst       0
# PC10_sst      0
# PC1_msl       0
# PC2_msl       0
# PC3_msl       0
# PC4_msl       0
# PC5_msl       0
# PC6_msl       0
# PC7_msl       0
# PC8_msl       0
# PC9_msl       0
# PC10_msl      0
# PC1_z         0
# PC2_z         0
# PC3_z         0
# PC4_z         0
# PC5_z         0
# PC6_z         0
# PC7_z         0
# PC8_z         0
# PC9_z         0
# PC10_z        0
# pwt_500hpa    0
# month_1       0
# month_2       0
# month_3       0
# month_4       0
# month_5       0
# month_6       0
# month_7       0
# month_8       0
# month_9       0
# month_10      0
# month_11      0
# month_12      0
# dtype: int64
# PC1_sst       float64
# PC2_sst       float64
# PC3_sst       float64
# PC4_sst       float64
# PC5_sst       float64
# PC6_sst       float64
# PC7_sst       float64
# PC8_sst       float64
# PC9_sst       float64
# PC10_sst      float64
# PC1_msl       float64
# PC2_msl       float64
# PC3_msl       float64
# PC4_msl       float64
# PC5_msl       float64
# PC6_msl       float64
# PC7_msl       float64
# PC8_msl       float64
# PC9_msl       float64
# PC10_msl      float64
# PC1_z         float64
# PC2_z         float64
# PC3_z         float64
# PC4_z         float64
# PC5_z         float64
# PC6_z         float64
# PC7_z         float64
# PC8_z         float64
# PC9_z         float64
# PC10_z        float64
# pwt_500hpa    float64
# month_1          bool
# month_2          bool
# month_3          bool
# month_4          bool
# month_5          bool
# month_6          bool
# month_7          bool
# month_8          bool
# month_9          bool
# month_10         bool
# month_11         bool
# month_12         bool
# dtype: object
#     PC1_sst   PC2_sst   PC3_sst   PC4_sst   PC5_sst   PC6_sst   PC7_sst  \
# 0  0.259173  0.635995  0.431253  0.605195  0.468394  0.450963  0.552845
# 1  0.297425  0.604696  0.368090  0.608731  0.524775  0.468598  0.522726
# 2  0.291333  0.660220  0.374712  0.550507  0.359033  0.560825  0.511349
# 3  0.310941  0.518791  0.416521  0.411727  0.288424  0.633701  0.453706
# 4  0.314177  0.318119  0.427844  0.399218  0.347708  0.638117  0.574364
#
#     PC8_sst   PC9_sst  PC10_sst  ...  month_3  month_4  month_5  month_6  \
# 0  0.414452  0.499316  0.399609  ...    False    False    False    False
# 1  0.454354  0.549438  0.483807  ...    False    False    False    False
# 2  0.435851  0.573838  0.458497  ...     True    False    False    False
# 3  0.457244  0.544118  0.454177  ...    False     True    False    False
# 4  0.388460  0.519845  0.464419  ...    False    False     True    False
#
#    month_7  month_8  month_9  month_10  month_11  month_12
# 0    False    False    False     False     False     False
# 1    False    False    False     False     False     False
# 2    False    False    False     False     False     False
# 3    False    False    False     False     False     False
# 4    False    False    False     False     False     False
#
# [5 rows x 43 columns]

# %%
# Initialize PyCaret setup
setup(data=automl_data, 
      target=target,
      session_id=123,
      normalize=False,        
      transformation=True,   
      fold=5,                
      verbose=True)
# Out:
# <style type="text/css">
# #T_4f9c4_row8_col1, #T_4f9c4_row12_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_4f9c4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4f9c4_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_4f9c4_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4f9c4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4f9c4_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_4f9c4_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_4f9c4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4f9c4_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_4f9c4_row1_col1" class="data row1 col1" >pwt_500hpa</td>
#     </tr>
#     <tr>
#       <th id="T_4f9c4_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_4f9c4_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_4f9c4_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_4f9c4_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_4f9c4_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_4f9c4_row3_col1" class="data row3 col1" >(636, 43)</td>
#     </tr>
#     <tr>
#       <th id="T_4f9c4_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_4f9c4_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_4f9c4_row4_col1" class="data row4 col1" >(636, 43)</td>
#     </tr>
#     <tr>
#       <th id="T_4f9c4_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_4f9c4_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_4f9c4_row5_col1" class="data row5 col1" >(445, 43)</td>
#     </tr>
#     <tr>
#       <th id="T_4f9c4_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_4f9c4_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_4f9c4_row6_col1" class="data row6 col1" >(191, 43)</td>
#     </tr>
#     <tr>
#       <th id="T_4f9c4_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_4f9c4_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_4f9c4_row7_col1" class="data row7 col1" >30</td>
#     </tr>
#     <tr>
#       <th id="T_4f9c4_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_4f9c4_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_4f9c4_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_4f9c4_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_4f9c4_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_4f9c4_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_4f9c4_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_4f9c4_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_4f9c4_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_4f9c4_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_4f9c4_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_4f9c4_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_4f9c4_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_4f9c4_row12_col0" class="data row12 col0" >Transformation</td>
#       <td id="T_4f9c4_row12_col1" class="data row12 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_4f9c4_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_4f9c4_row13_col0" class="data row13 col0" >Transformation method</td>
#       <td id="T_4f9c4_row13_col1" class="data row13 col1" >yeo-johnson</td>
#     </tr>
#     <tr>
#       <th id="T_4f9c4_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_4f9c4_row14_col0" class="data row14 col0" >Fold Generator</td>
#       <td id="T_4f9c4_row14_col1" class="data row14 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_4f9c4_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_4f9c4_row15_col0" class="data row15 col0" >Fold Number</td>
#       <td id="T_4f9c4_row15_col1" class="data row15 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_4f9c4_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_4f9c4_row16_col0" class="data row16 col0" >CPU Jobs</td>
#       <td id="T_4f9c4_row16_col1" class="data row16 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_4f9c4_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_4f9c4_row17_col0" class="data row17 col0" >Use GPU</td>
#       <td id="T_4f9c4_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_4f9c4_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_4f9c4_row18_col0" class="data row18 col0" >Log Experiment</td>
#       <td id="T_4f9c4_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_4f9c4_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_4f9c4_row19_col0" class="data row19 col0" >Experiment Name</td>
#       <td id="T_4f9c4_row19_col1" class="data row19 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_4f9c4_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_4f9c4_row20_col0" class="data row20 col0" >USI</td>
#       <td id="T_4f9c4_row20_col1" class="data row20 col1" >94cb</td>
#     </tr>
#   </tbody>
# </table>

# %%
best = compare_models(exclude = ['ransac'])
# Out:
# <style type="text/css">
# #T_d8325 th {
#   text-align: left;
# }
# #T_d8325_row0_col0, #T_d8325_row1_col0, #T_d8325_row1_col1, #T_d8325_row1_col2, #T_d8325_row1_col3, #T_d8325_row1_col4, #T_d8325_row1_col5, #T_d8325_row1_col6, #T_d8325_row2_col0, #T_d8325_row2_col1, #T_d8325_row2_col2, #T_d8325_row2_col3, #T_d8325_row2_col4, #T_d8325_row2_col5, #T_d8325_row2_col6, #T_d8325_row3_col0, #T_d8325_row3_col1, #T_d8325_row3_col2, #T_d8325_row3_col3, #T_d8325_row3_col4, #T_d8325_row3_col5, #T_d8325_row3_col6, #T_d8325_row4_col0, #T_d8325_row4_col1, #T_d8325_row4_col2, #T_d8325_row4_col3, #T_d8325_row4_col4, #T_d8325_row4_col5, #T_d8325_row4_col6, #T_d8325_row5_col0, #T_d8325_row5_col1, #T_d8325_row5_col2, #T_d8325_row5_col3, #T_d8325_row5_col4, #T_d8325_row5_col5, #T_d8325_row5_col6, #T_d8325_row6_col0, #T_d8325_row6_col1, #T_d8325_row6_col2, #T_d8325_row6_col3, #T_d8325_row6_col4, #T_d8325_row6_col5, #T_d8325_row6_col6, #T_d8325_row7_col0, #T_d8325_row7_col1, #T_d8325_row7_col2, #T_d8325_row7_col3, #T_d8325_row7_col4, #T_d8325_row7_col5, #T_d8325_row7_col6, #T_d8325_row8_col0, #T_d8325_row8_col1, #T_d8325_row8_col2, #T_d8325_row8_col3, #T_d8325_row8_col4, #T_d8325_row8_col5, #T_d8325_row8_col6, #T_d8325_row9_col0, #T_d8325_row9_col1, #T_d8325_row9_col2, #T_d8325_row9_col3, #T_d8325_row9_col4, #T_d8325_row9_col5, #T_d8325_row9_col6, #T_d8325_row10_col0, #T_d8325_row10_col1, #T_d8325_row10_col2, #T_d8325_row10_col3, #T_d8325_row10_col4, #T_d8325_row10_col5, #T_d8325_row10_col6, #T_d8325_row11_col0, #T_d8325_row11_col1, #T_d8325_row11_col2, #T_d8325_row11_col3, #T_d8325_row11_col4, #T_d8325_row11_col5, #T_d8325_row11_col6, #T_d8325_row12_col0, #T_d8325_row12_col1, #T_d8325_row12_col2, #T_d8325_row12_col3, #T_d8325_row12_col4, #T_d8325_row12_col5, #T_d8325_row12_col6, #T_d8325_row13_col0, #T_d8325_row13_col1, #T_d8325_row13_col2, #T_d8325_row13_col3, #T_d8325_row13_col4, #T_d8325_row13_col5, #T_d8325_row13_col6, #T_d8325_row14_col0, #T_d8325_row14_col1, #T_d8325_row14_col2, #T_d8325_row14_col3, #T_d8325_row14_col4, #T_d8325_row14_col5, #T_d8325_row14_col6, #T_d8325_row15_col0, #T_d8325_row15_col1, #T_d8325_row15_col2, #T_d8325_row15_col3, #T_d8325_row15_col4, #T_d8325_row15_col5, #T_d8325_row15_col6, #T_d8325_row16_col0, #T_d8325_row16_col1, #T_d8325_row16_col2, #T_d8325_row16_col3, #T_d8325_row16_col4, #T_d8325_row16_col5, #T_d8325_row16_col6, #T_d8325_row17_col0, #T_d8325_row17_col1, #T_d8325_row17_col2, #T_d8325_row17_col3, #T_d8325_row17_col4, #T_d8325_row17_col5, #T_d8325_row17_col6, #T_d8325_row18_col0, #T_d8325_row18_col1, #T_d8325_row18_col2, #T_d8325_row18_col3, #T_d8325_row18_col4, #T_d8325_row18_col5, #T_d8325_row18_col6, #T_d8325_row19_col0, #T_d8325_row19_col1, #T_d8325_row19_col2, #T_d8325_row19_col3, #T_d8325_row19_col4, #T_d8325_row19_col5, #T_d8325_row19_col6 {
#   text-align: left;
# }
# #T_d8325_row0_col1, #T_d8325_row0_col2, #T_d8325_row0_col3, #T_d8325_row0_col4, #T_d8325_row0_col5, #T_d8325_row0_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_d8325_row0_col7, #T_d8325_row1_col7, #T_d8325_row2_col7, #T_d8325_row3_col7, #T_d8325_row4_col7, #T_d8325_row5_col7, #T_d8325_row6_col7, #T_d8325_row7_col7, #T_d8325_row8_col7, #T_d8325_row9_col7, #T_d8325_row10_col7, #T_d8325_row12_col7, #T_d8325_row13_col7, #T_d8325_row14_col7, #T_d8325_row15_col7, #T_d8325_row16_col7, #T_d8325_row17_col7, #T_d8325_row18_col7, #T_d8325_row19_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_d8325_row11_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_d8325">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d8325_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_d8325_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_d8325_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_d8325_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_d8325_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_d8325_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_d8325_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_d8325_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d8325_level0_row0" class="row_heading level0 row0" >huber</th>
#       <td id="T_d8325_row0_col0" class="data row0 col0" >Huber Regressor</td>
#       <td id="T_d8325_row0_col1" class="data row0 col1" >0.0927</td>
#       <td id="T_d8325_row0_col2" class="data row0 col2" >0.0148</td>
#       <td id="T_d8325_row0_col3" class="data row0 col3" >0.1216</td>
#       <td id="T_d8325_row0_col4" class="data row0 col4" >0.3423</td>
#       <td id="T_d8325_row0_col5" class="data row0 col5" >0.0823</td>
#       <td id="T_d8325_row0_col6" class="data row0 col6" >0.2251</td>
#       <td id="T_d8325_row0_col7" class="data row0 col7" >0.0300</td>
#     </tr>
#     <tr>
#       <th id="T_d8325_level0_row1" class="row_heading level0 row1" >br</th>
#       <td id="T_d8325_row1_col0" class="data row1 col0" >Bayesian Ridge</td>
#       <td id="T_d8325_row1_col1" class="data row1 col1" >0.0942</td>
#       <td id="T_d8325_row1_col2" class="data row1 col2" >0.0151</td>
#       <td id="T_d8325_row1_col3" class="data row1 col3" >0.1226</td>
#       <td id="T_d8325_row1_col4" class="data row1 col4" >0.3318</td>
#       <td id="T_d8325_row1_col5" class="data row1 col5" >0.0827</td>
#       <td id="T_d8325_row1_col6" class="data row1 col6" >0.2326</td>
#       <td id="T_d8325_row1_col7" class="data row1 col7" >0.0240</td>
#     </tr>
#     <tr>
#       <th id="T_d8325_level0_row2" class="row_heading level0 row2" >lr</th>
#       <td id="T_d8325_row2_col0" class="data row2 col0" >Linear Regression</td>
#       <td id="T_d8325_row2_col1" class="data row2 col1" >0.0943</td>
#       <td id="T_d8325_row2_col2" class="data row2 col2" >0.0151</td>
#       <td id="T_d8325_row2_col3" class="data row2 col3" >0.1229</td>
#       <td id="T_d8325_row2_col4" class="data row2 col4" >0.3305</td>
#       <td id="T_d8325_row2_col5" class="data row2 col5" >0.0831</td>
#       <td id="T_d8325_row2_col6" class="data row2 col6" >0.2327</td>
#       <td id="T_d8325_row2_col7" class="data row2 col7" >1.6120</td>
#     </tr>
#     <tr>
#       <th id="T_d8325_level0_row3" class="row_heading level0 row3" >ridge</th>
#       <td id="T_d8325_row3_col0" class="data row3 col0" >Ridge Regression</td>
#       <td id="T_d8325_row3_col1" class="data row3 col1" >0.0973</td>
#       <td id="T_d8325_row3_col2" class="data row3 col2" >0.0161</td>
#       <td id="T_d8325_row3_col3" class="data row3 col3" >0.1267</td>
#       <td id="T_d8325_row3_col4" class="data row3 col4" >0.2873</td>
#       <td id="T_d8325_row3_col5" class="data row3 col5" >0.0855</td>
#       <td id="T_d8325_row3_col6" class="data row3 col6" >0.2426</td>
#       <td id="T_d8325_row3_col7" class="data row3 col7" >0.0240</td>
#     </tr>
#     <tr>
#       <th id="T_d8325_level0_row4" class="row_heading level0 row4" >omp</th>
#       <td id="T_d8325_row4_col0" class="data row4 col0" >Orthogonal Matching Pursuit</td>
#       <td id="T_d8325_row4_col1" class="data row4 col1" >0.0967</td>
#       <td id="T_d8325_row4_col2" class="data row4 col2" >0.0163</td>
#       <td id="T_d8325_row4_col3" class="data row4 col3" >0.1275</td>
#       <td id="T_d8325_row4_col4" class="data row4 col4" >0.2740</td>
#       <td id="T_d8325_row4_col5" class="data row4 col5" >0.0859</td>
#       <td id="T_d8325_row4_col6" class="data row4 col6" >0.2389</td>
#       <td id="T_d8325_row4_col7" class="data row4 col7" >0.0240</td>
#     </tr>
#     <tr>
#       <th id="T_d8325_level0_row5" class="row_heading level0 row5" >et</th>
#       <td id="T_d8325_row5_col0" class="data row5 col0" >Extra Trees Regressor</td>
#       <td id="T_d8325_row5_col1" class="data row5 col1" >0.0995</td>
#       <td id="T_d8325_row5_col2" class="data row5 col2" >0.0175</td>
#       <td id="T_d8325_row5_col3" class="data row5 col3" >0.1323</td>
#       <td id="T_d8325_r

# %%
evaluate_model(best)

# print hyperparameters of best model
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…
